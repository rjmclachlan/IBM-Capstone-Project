# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
import folium # plotting library
    
# tranforming json file into a pandas dataframe library
from pandas import json_normalize


import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

print('Libraries imported.')
# Out:
# Libraries imported.

# %%
CLIENT_ID = 'PQ05J4YNJMO22NWSMAYDERTCAU3FPRQO5VDVIDIGOBOBLCKZ' # your Foursquare ID
CLIENT_SECRET = 'ZDKTYSQ3AXJCTCYFLBCQA2QXRT4FPZWUUW4RAA4O2QDRCVFA' # your Foursquare Secret
VERSION = '20200603'
LIMIT = 200
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: PQ05J4YNJMO22NWSMAYDERTCAU3FPRQO5VDVIDIGOBOBLCKZ
# CLIENT_SECRET:ZDKTYSQ3AXJCTCYFLBCQA2QXRT4FPZWUUW4RAA4O2QDRCVFA

# %%
#Geocoders is Spotty on this environment.  So I used a different a different environment to solve this problem.

address = '540 San Pablo Ave, Albany, CA'

latitude = 37.8961913
longitude = -122.3010785


#from geopy.geocoders import Nominatim # convert an address into latitude and longitude values
#geolocator = Nominatim(user_agent="foursquare_agent")
#location = geolocator.geocode(address)
#latitude = location.latitude
#longitude = location.longitude

print(latitude, longitude)
# Out:
# 37.8961913 -122.3010785

# %%
search_query = 'Restaurant'
radius = 1000
LIMIT = 500
print(search_query + ' .... OK!')
# Out:
# Restaurant .... OK!

# %% [markdown]
# ## Foursquare Search

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=PQ05J4YNJMO22NWSMAYDERTCAU3FPRQO5VDVIDIGOBOBLCKZ&client_secret=ZDKTYSQ3AXJCTCYFLBCQA2QXRT4FPZWUUW4RAA4O2QDRCVFA&ll=37.8961913,-122.3010785&v=20200603&query=Restaurant&radius=1000&limit=500'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5ed93d5a0a2972001b9eb79d'},
#  'response': {'venues': [{'id': '4b37dad4f964a520834725e3',
#     'name': 'Asian Pearl Seafood Restaurant 顺峰漁村',
#     'location': {'address': '3288 Pierce St Ste A118',
#      'crossStreet': 'Central Ave.',
#      'lat': 37.89875495103815,
#      'lng': -122.30759232594136,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.89875495103815,
#        'lng': -122.30759232594136}],
#      'distance': 639,
#      'postalCode': '94804',
#      'cc': 'US',
#      'city': 'Richmond',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['3288 Pierce St Ste A118 (Central Ave.)',
#       'Richmond, CA 94804',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1f5931735',
#       'name': 'Dim Sum Restaurant',
#       'pluralName': 'Dim Sum Restaurants',
#       'shortName': 'Dim Sum',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dimsum_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591295508',
#     'hasPerk': False},
#    {'id': '4e0a32ad22714194998c521c',
#     'name': 'Golden Grain Restaurant Inc.',
#     'location': {'address': '917 San Pablo Ave',
#      'lat': 37.889525533333334,
#      'lng': -122.29856123333333,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.889525533333334,
#        'lng': -122.29856123333333}],
#      'distance': 774,
#      'postalCode': '94706',
#      'cc': 'US',
#      'city': 'Albany',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['917 San Pablo Ave',
#       'Albany, CA 94706',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591295508',
#     'hasPerk': False},
#    {'id': '4ae38d8df964a5208f9621e3',
#     'name': 'DaNang Restaurant',
#     'location': {'address': '905 San Pablo Ave',
#      'crossStreet': 'btw Buchanan St & Solano Ave',
#      'lat': 37.89000635553116,
#      'lng': -122.29874158460096,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.89000635553116,
#        'lng': -122.29874158460096},
#       {'label': 'entrance', 'lat': 37.890071, 'lng': -122.298707}],
#      'distance': 718,
#      'postalCode': '94706',
#      'cc': 'US',
#      'city': 'Albany',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['905 San Pablo Ave (btw Buchanan St & Solano Ave)',
#       'Albany, CA 94706',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d149941735',
#       'name': 'Thai Restaurant',
#       'pluralName': 'Thai Restaurants',
#       'shortName': 'Thai',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591295508',
#     'hasPerk': False},
#    {'id': '4b9d4208f964a520b59d36e3',
#     'name': 'L&L Chinese Seafood Restaurant',
#     'location': {'address': '10140 San Pablo Ave',
#      'lat': 37.903049002340964,
#      'lng': -122.30343019958578,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.903049002340964,
#        'lng': -122.30343019958578},
#       {'label': 'entrance', 'lat': 37.903045, 'lng': -122.303508}],
#      'distance': 790,
#      'postalCode': '94530',
#      'cc': 'US',
#      'city': 'El Cerrito',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['10140 San Pablo Ave',
#       'El Cerrito, CA 94530',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1f5931735',
#       'name': 'Dim Sum Restaurant',
#       'pluralName': 'Dim Sum Restaurants',
#       'shortName': 'Dim Sum',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dimsum_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591295508',
#     'hasPerk': False},
#    {'id': '4a63dc5cf964a520efc51fe3',
#     'name': "Fat Apple's Restaurant & Bakery",
#     'location': {'address': '7525 Fairmount Ave',
#      'lat': 37.90413410169567,
#      'lng': -122.29166714532913,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.90413410169567,
#        'lng': -122.29166714532913},
#       {'label': 'entrance', 'lat': 37.904051, 'lng': -122.291689}],
#      'distance': 1210,
#      'postalCode': '94530',
#      'cc': 'US',
#      'city': 'El Cerrito',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['7525 Fairmount Ave',
#       'El Cerrito, CA 94530',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d143941735',
#       'name': 'Breakfast Spot',
#       'pluralName': 'Breakfast Spots',
#       'shortName': 'Breakfast',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/breakfast_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591295508',
#     'hasPerk': False},
#    {'id': '4a76272ff964a52068e21fe3',
#     'name': 'Daimo Chinese Restaurant',
#     'location': {'address': '3288 Pierce St',
#      'crossStreet': 'at Central Ave',
#      'lat': 37.89920632527881,
#      'lng': -122.3088164830254,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.89920632527881,
#        'lng': -122.3088164830254}],
#      'distance': 758,
#      'postalCode': '94804',
#      'cc': 'US',
#      'city': 'Richmond',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['3288 Pierce St (at Central Ave)',
#       'Richmond, CA 94804',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '1275424',
#      'url': 'https://www.grubhub.com/restaurant/daimo-chinese-restaurant-3288-pierce-st-richmond/1275424?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1275424',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1591295508',
#     'hasPerk': False},
#    {'id': '52239a12498e5bad72298d8d',
#     'name': 'Restaurant  Valparaiso',
#     'location': {'address': '1403 Solano Ave',
#      'crossStreet': 'at Carmel',
#      'lat': 37.89091859080728,
#      'lng': -122.28991873998577,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.89091859080728,
#        'lng': -122.28991873998577}],
#      'distance': 1142,
#      'postalCode': '94706',
#      'cc': 'US',
#      'city': 'Albany',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['1403 Solano Ave (at Carmel)',
#       'Albany, CA 94706',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1cd941735',
#       'name': 'South American Restaurant',
#       'pluralName': 'South American Restaurants',
#       'shortName': 'South American',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/argentinian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '122956798'},
#     'referralId': 'v-1591295508',
#     'hasPerk': False},
#    {'id': '4f329c5819836c91c7e8994b',
#     'name': 'Niki Japanese Restaurant',
#     'location': {'address': '809 San Pablo Ave',
#      'lat': 37.891523,
#      'lng': -122.299339,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.891523,
#        'lng': -122.299339},
#       {'label': 'entrance', 'lat': 37.891459, 'lng': -122.299151}],
#      'distance': 541,
#      'postalCode': '94706',
#      'cc': 'US',
#      'city': 'Albany',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['809 San Pablo Ave',
#       'Albany, CA 94706',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d111941735',
#       'name': 'Japanese Restaurant',
#       'pluralName': 'Japanese Restaurants',
#       'shortName': 'Japanese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591295508',
#     'hasPerk': False},
#    {'id': '4a45b266f964a52075a81fe3',
#     'name': "Ferratt's Tapas & Restaurant",
#     'location': {'address': '854 San Pablo Ave',
#      'crossStreet': 'Solano Ave',
#      'lat': 37.890394,
#      'lng': -122.29948600000002,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.890394,
#        'lng': -122.29948600000002},
#       {'label': 'entrance', 'lat': 37.89051, 'lng': -122.299199}],
#      'distance': 660,
#      'postalCode': '94706',
#      'cc': 'US',
#      'city': 'Albany',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['854 San Pablo Ave (Solano Ave)',
#       'Albany, CA 94706',
#       'United States']},
#     'categories': [],
#     'referralId': 'v-1591295508',
#     'hasPerk': False},
#    {'id': '501994e7e4b00b6bfd7760a9',
#     'name': 'Sumo Japanese Restaurant',
#     'location': {'address': '977 San Pablo Ave',
#      'crossStreet': 'Buchanan',
#      'lat': 37.887582997713565,
#      'lng': -122.2978960512304,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.887582997713565,
#        'lng': -122.2978960512304},
#       {'label': 'entrance', 'lat': 37.887571, 'lng': -122.297912}],
#      'distance': 998,
#      'postalCode': '94706',
#      'cc': 'US',
#      'city': 'Albany',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['977 San Pablo Ave (Buchanan)',
#       'Albany, CA 94706',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d111941735',
#       'name': 'Japanese Restaurant',
#       'pluralName': 'Japanese Restaurants',
#       'shortName': 'Japanese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '271903',
#      'url': 'https://www.grubhub.com/restaurant/sumo-japanese-restaurant-977-san-pablo-ave-albany/271903?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=271903',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1591295508',
#     'hasPerk': False},
#    {'id': '4bf19fcb78cec92891a0ba86',
#     'name': 'Chika Japanese Restaurant',
#     'location': {'address': '3288 Pierce St Ste A107',
#      'lat': 37.899047869609824,
#      'lng': -122.30739165330048,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.899047869609824,
#        'lng': -122.30739165330048}],
#      'distance': 639,
#      'postalCode': '94804',
#      'cc': 'US',
#      'city': 'Richmond',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['3288 Pierce St Ste A107',
#       'Richmond, CA 94804',
#       'United States']},
#     'categories': [{'id': '55a59bace4b013909087cb24',
#       'name': 'Ramen Restaurant',
#       'pluralName': 'Ramen Restaurants',
#       'shortName': 'Ramen',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/ramen_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591295508',
#     'hasPerk': False},
#    {'id': '4a9df122f964a520dd3920e3',
#     'name': 'Sugata Japanese Restaurant',
#     'location': {'address': '1105 Solano Ave',
#      'lat': 37.89051,
#      'lng': -122.298674,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.89051,
#        'lng': -122.298674},
#       {'label': 'entrance', 'lat': 37.890398, 'lng': -122.298697}],
#      'distance': 666,
#      'postalCode': '94706',
#      'cc': 'US',
#      'city': 'Albany',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['1105 Solano Ave',
#       'Albany, CA 94706',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d111941735',
#       'name': 'Japanese Restaurant',
#       'pluralName': 'Japanese Restaurants',
#       'shortName': 'Japanese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '1279944',
#      'url': 'https://www.grubhub.com/restaurant/sugata-1105-solano-ave-albany/1279944?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1279944',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1591295508',
#     'hasPerk': False},
#    {'id': '4f32b05519836c91c7f0120f',
#     'name': 'Golden Dynasty Restaurant',
#     'location': {'address': '10140 San Pablo Ave',
#      'lat': 37.90313,
#      'lng': -122.303386,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.90313,
#        'lng': -122.303386}],
#      'distance': 798,
#      'postalCode': '94530',
#      'cc': 'US',
#      'city': 'El Cerrito',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['10140 San Pablo Ave',
#       'El Cerrito, CA 94530',
#       'United States']},
#     'categories': [{'id': '4d4b7105d754a06374d81259',
#       'name': 'Food',
#       'pluralName': 'Food',
#       'shortName': 'Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591295508',
#     'hasPerk': False},
#    {'id': '4bc1339fabf495217cc7c093',
#     'name': 'Kasuga Japanese Restaurant',
#     'location': {'address': '938 San Pablo Ave',
#      'lat': 37.888883,
#      'lng': -122.29879199999999,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.888883,
#        'lng': -122.29879199999999}],
#      'distance': 837,
#      'postalCode': '94706',
#      'cc': 'US',
#      'city': 'Albany',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['938 San Pablo Ave',
#       'Albany, CA 94706',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d111941735',
#       'name': 'Japanese Restaurant',
#       'pluralName': 'Japanese Restaurants',
#       'shortName': 'Japanese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591295508',
#     'hasPerk': False},
#    {'id': '4cbfa7d19ca85481a714b816',
#     'name': 'Nông Thôn Vietnamese Restaurant',
#     'location': {'address': '10086 San Pablo Ave',
#      'crossStreet': 'at Central Ave.',
#      'lat': 37.90212170109282,
#      'lng': -122.30310127642726,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.90212170109282,
#        'lng': -122.30310127642726}],
#      'distance': 683,
#      'postalCode': '94530',
#      'cc': 'US',
#      'city': 'El Cerrito',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['10086 San Pablo Ave (at Central Ave.)',
#       'El Cerrito, CA 94530',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d14a941735',
#       'name': 'Vietnamese Restaurant',
#       'pluralName': 'Vietnamese Restaurants',
#       'shortName': 'Vietnamese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vietnamese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591295508',
#     'hasPerk': False},
#    {'id': '51d35be7498ed50ed1db6cd3',
#     'name': 'China Village Restaurant',
#     'location': {'address': '1335 Solano Ave',
#      'crossStreet': 'at Ramona Ave',
#      'lat': 37.8908313286842,
#      'lng': -122.291233943932,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.8908313286842,
#        'lng': -122.291233943932},
#       {'label': 'entrance', 'lat': 37.890825, 'lng': -122.291193}],
#      'distance': 1050,
#      'postalCode': '94706',
#      'cc': 'US',
#      'city': 'Albany',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['1335 Solano Ave (at Ramona Ave)',
#       'Albany, CA 94706',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '1524814',
#      'url': 'https://www.grubhub.com/restaurant/china-village-1335-solano-avenue-albany/1524814?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1524814',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1591295508',
#     'hasPerk': False},
#    {'id': '4b9c49b7f964a520315c36e3',
#     'name': 'Kathmandu Restaurant',
#     'location': {'address': '1410 Solano Ave',
#      'lat': 37.890646999999994,
#      'lng': -122.289153,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.890646999999994,
#        'lng': -122.289153}],
#      'distance': 1215,
#      'postalCode': '94706',
#      'cc': 'US',
#      'city': 'Albany',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['1410 Solano Ave',
#       'Albany, CA 94706',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '557107',
#      'url': 'https://www.grubhub.com/restaurant/kathmandu-restaurant-1410-b-solano-ave-albany/557107?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=557107',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1591295508',
#     'hasPerk': False},
#    {'id': '4acba3a9f964a520bcc420e3',
#     'name': 'Pho Saigon 2',
#     'location': {'address': '3288 Pierce St Ste A116',
#      'lat': 37.899096317332734,
#      'lng': -122.30712705032536,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.899096317332734,
#        'lng': -122.30712705032536}],
#      'distance': 621,
#      'postalCode': '94804',
#      'cc': 'US',
#      'city': 'Richmond',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['3288 Pierce St Ste A116',
#       'Richmond, CA 94804',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d14a941735',
#       'name': 'Vietnamese Restaurant',
#       'pluralName': 'Vietnamese Restaurants',
#       'shortName': 'Vietnamese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vietnamese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591295508',
#     'hasPerk': False},
#    {'id': '4c5e06927f661b8d6f364d1c',
#     'name': 'Saigon Seafood Harbor',
#     'location': {'address': '3150 Pierce St',
#      'crossStreet': 'Central Ave',
#      'lat': 37.900488710469965,
#      'lng': -122.30896781797568,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.900488710469965,
#        'lng': -122.30896781797568}],
#      'distance': 842,
#      'postalCode': '94804',
#      'cc': 'US',
#      'city': 'Richmond',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['3150 Pierce St (Central Ave)',
#       'Richmond, CA 94804',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '563663',
#      'url': 'https://www.grubhub.com/restaurant/saigon-seafood-harbor-restaurant-3150-pierce-st-richmond/563663?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=563663',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1591295508',
#     'hasPerk': False},
#    {'id': '578008a7498efd93529024bf',
#     'name': 'Zaytoon',
#     'location': {'address': '1133 Solano Ave',
#      'lat': 37.89050032258931,
#      'lng': -122.29776391298495,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.89050032258931,
#        'lng': -122.29776391298495},
#       {'label': 'entrance', 'lat': 37.890457, 'lng': -122.297772}],
#      'distance': 697,
#      'postalCode': '94706',
#      'cc': 'US',
#      'city': 'Albany',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['1133 Solano Ave',
#       'Albany, CA 94706',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1c0941735',
#       'name': 'Mediterranean Restaurant',
#       'pluralName': 'Mediterranean Restaurants',
#       'shortName': 'Mediterranean',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mediterranean_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '2034386',
#      'url': 'https://www.grubhub.com/restaurant/zaytoon-mediterranean-restaurant-1133-solano-ave-albany/2034386?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2034386',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1591295508',
#     'hasPerk': False},
#    {'id': '4c6ccdd065eda0938d0d4dd0',
#     'name': 'Britt-Maries',
#     'location': {'address': '1369 Solano Ave',
#      'lat': 37.890966999999996,
#      'lng': -122.29053400000001,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.890966999999996,
#        'lng': -122.29053400000001}],
#      'distance': 1093,
#      'postalCode': '94706',
#      'cc': 'US',
#      'city': 'Albany',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['1369 Solano Ave',
#       'Albany, CA 94706',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591295508',
#     'hasPerk': False}]}}

# %%
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                          id                                 name  \
# 0  4b37dad4f964a520834725e3  Asian Pearl Seafood Restaurant 顺峰漁村
# 1  4e0a32ad22714194998c521c         Golden Grain Restaurant Inc.
# 2  4ae38d8df964a5208f9621e3                    DaNang Restaurant
# 3  4b9d4208f964a520b59d36e3       L&L Chinese Seafood Restaurant
# 4  4a63dc5cf964a520efc51fe3      Fat Apple's Restaurant & Bakery
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1f5931735', 'name': 'D...  v-1591295508    False
# 1  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...  v-1591295508    False
# 2  [{'id': '4bf58dd8d48988d149941735', 'name': 'T...  v-1591295508    False
# 3  [{'id': '4bf58dd8d48988d1f5931735', 'name': 'D...  v-1591295508    False
# 4  [{'id': '4bf58dd8d48988d143941735', 'name': 'B...  v-1591295508    False
#
#           location.address          location.crossStreet  location.lat  \
# 0  3288 Pierce St Ste A118                  Central Ave.     37.898755
# 1        917 San Pablo Ave                           NaN     37.889526
# 2        905 San Pablo Ave  btw Buchanan St & Solano Ave     37.890006
# 3      10140 San Pablo Ave                           NaN     37.903049
# 4       7525 Fairmount Ave                           NaN     37.904134
#
#    location.lng                            location.labeledLatLngs  ...  \
# 0   -122.307592  [{'label': 'display', 'lat': 37.89875495103815...  ...
# 1   -122.298561  [{'label': 'display', 'lat': 37.88952553333333...  ...
# 2   -122.298742  [{'label': 'display', 'lat': 37.89000635553116...  ...
# 3   -122.303430  [{'label': 'display', 'lat': 37.90304900234096...  ...
# 4   -122.291667  [{'label': 'display', 'lat': 37.90413410169567...  ...
#
#    location.state location.country  \
# 0              CA    United States
# 1              CA    United States
# 2              CA    United States
# 3              CA    United States
# 4              CA    United States
#
#                            location.formattedAddress delivery.id delivery.url  \
# 0  [3288 Pierce St Ste A118 (Central Ave.), Richm...         NaN          NaN
# 1  [917 San Pablo Ave, Albany, CA 94706, United S...         NaN          NaN
# 2  [905 San Pablo Ave (btw Buchanan St & Solano A...         NaN          NaN
# 3  [10140 San Pablo Ave, El Cerrito, CA 94530, Un...         NaN          NaN
# 4  [7525 Fairmount Ave, El Cerrito, CA 94530, Uni...         NaN          NaN
#
#   delivery.provider.name delivery.provider.icon.prefix  \
# 0                    NaN                           NaN
# 1                    NaN                           NaN
# 2                    NaN                           NaN
# 3                    NaN                           NaN
# 4                    NaN                           NaN
#
#   delivery.provider.icon.sizes delivery.provider.icon.name venuePage.id
# 0                          NaN                         NaN          NaN
# 1                          NaN                         NaN          NaN
# 2                          NaN                         NaN          NaN
# 3                          NaN                         NaN          NaN
# 4                          NaN                         NaN          NaN
#
# [5 rows x 24 columns]

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                                    name                 categories  \
# 0   Asian Pearl Seafood Restaurant 顺峰漁村         Dim Sum Restaurant
# 1          Golden Grain Restaurant Inc.         Chinese Restaurant
# 2                     DaNang Restaurant            Thai Restaurant
# 3        L&L Chinese Seafood Restaurant         Dim Sum Restaurant
# 4       Fat Apple's Restaurant & Bakery             Breakfast Spot
# 5              Daimo Chinese Restaurant         Chinese Restaurant
# 6                Restaurant  Valparaiso  South American Restaurant
# 7              Niki Japanese Restaurant        Japanese Restaurant
# 8          Ferratt's Tapas & Restaurant                       None
# 9              Sumo Japanese Restaurant        Japanese Restaurant
# 10            Chika Japanese Restaurant           Ramen Restaurant
# 11           Sugata Japanese Restaurant        Japanese Restaurant
# 12            Golden Dynasty Restaurant                       Food
# 13           Kasuga Japanese Restaurant        Japanese Restaurant
# 14      Nông Thôn Vietnamese Restaurant      Vietnamese Restaurant
# 15             China Village Restaurant         Chinese Restaurant
# 16                 Kathmandu Restaurant                 Restaurant
# 17                         Pho Saigon 2      Vietnamese Restaurant
# 18                Saigon Seafood Harbor         Chinese Restaurant
# 19                              Zaytoon   Mediterranean Restaurant
# 20                         Britt-Maries                       Café
#
#                     address                   crossStreet        lat  \
# 0   3288 Pierce St Ste A118                  Central Ave.  37.898755
# 1         917 San Pablo Ave                           NaN  37.889526
# 2         905 San Pablo Ave  btw Buchanan St & Solano Ave  37.890006
# 3       10140 San Pablo Ave                           NaN  37.903049
# 4        7525 Fairmount Ave                           NaN  37.904134
# 5            3288 Pierce St                at Central Ave  37.899206
# 6           1403 Solano Ave                     at Carmel  37.890919
# 7         809 San Pablo Ave                           NaN  37.891523
# 8         854 San Pablo Ave                    Solano Ave  37.890394
# 9         977 San Pablo Ave                      Buchanan  37.887583
# 10  3288 Pierce St Ste A107                           NaN  37.899048
# 11          1105 Solano Ave                           NaN  37.890510
# 12      10140 San Pablo Ave                           NaN  37.903130
# 13        938 San Pablo Ave                           NaN  37.888883
# 14      10086 San Pablo Ave               at Central Ave.  37.902122
# 15          1335 Solano Ave                 at Ramona Ave  37.890831
# 16          1410 Solano Ave                           NaN  37.890647
# 17  3288 Pierce St Ste A116                           NaN  37.899096
# 18           3150 Pierce St                   Central Ave  37.900489
# 19          1133 Solano Ave                           NaN  37.890500
# 20          1369 Solano Ave                           NaN  37.890967
#
#            lng                                     labeledLatLngs  distance  \
# 0  -122.307592  [{'label': 'display', 'lat': 37.89875495103815...       639
# 1  -122.298561  [{'label': 'display', 'lat': 37.88952553333333...       774
# 2  -122.298742  [{'label': 'display', 'lat': 37.89000635553116...       718
# 3  -122.303430  [{'label': 'display', 'lat': 37.90304900234096...       790
# 4  -122.291667  [{'label': 'display', 'lat': 37.90413410169567...      1210
# 5  -122.308816  [{'label': 'display', 'lat': 37.89920632527881...       758
# 6  -122.289919  [{'label': 'display', 'lat': 37.89091859080728...      1142
# 7  -122.299339  [{'label': 'display', 'lat': 37.891523, 'lng':...       541
# 8  -122.299486  [{'label': 'display', 'lat': 37.890394, 'lng':...       660
# 9  -122.297896  [{'label': 'display', 'lat': 37.88758299771356...       998
# 10 -122.307392  [{'label': 'display', 'lat': 37.89904786960982...       639
# 11 -122.298674  [{'label': 'display', 'lat': 37.89051, 'lng': ...       666
# 12 -122.303386  [{'label': 'display', 'lat': 37.90313, 'lng': ...       798
# 13 -122.298792  [{'label': 'display', 'lat': 37.888883, 'lng':...       837
# 14 -122.303101  [{'label': 'display', 'lat': 37.90212170109282...       683
# 15 -122.291234  [{'label': 'display', 'lat': 37.8908313286842,...      1050
# 16 -122.289153  [{'label': 'display', 'lat': 37.89064699999999...      1215
# 17 -122.307127  [{'label': 'display', 'lat': 37.89909631733273...       621
# 18 -122.308968  [{'label': 'display', 'lat': 37.90048871046996...       842
# 19 -122.297764  [{'label': 'display', 'lat': 37.89050032258931...       697
# 20 -122.290534  [{'label': 'display', 'lat': 37.89096699999999...      1093
#
#    postalCode  cc        city state        country  \
# 0       94804  US    Richmond    CA  United States
# 1       94706  US      Albany    CA  United States
# 2       94706  US      Albany    CA  United States
# 3       94530  US  El Cerrito    CA  United States
# 4       94530  US  El Cerrito    CA  United States
# 5       94804  US    Richmond    CA  United States
# 6       94706  US      Albany    CA  United States
# 7       94706  US      Albany    CA  United States
# 8       94706  US      Albany    CA  United States
# 9       94706  US      Albany    CA  United States
# 10      94804  US    Richmond    CA  United States
# 11      94706  US      Albany    CA  United States
# 12      94530  US  El Cerrito    CA  United States
# 13      94706  US      Albany    CA  United States
# 14      94530  US  El Cerrito    CA  United States
# 15      94706  US      Albany    CA  United States
# 16      94706  US      Albany    CA  United States
# 17      94804  US    Richmond    CA  United States
# 18      94804  US    Richmond    CA  United States
# 19      94706  US      Albany    CA  United States
# 20      94706  US      Albany    CA  United States
#
#                                      formattedAddress  \
# 0   [3288 Pierce St Ste A118 (Central Ave.), Richm...
# 1   [917 San Pablo Ave, Albany, CA 94706, United S...
# 2   [905 San Pablo Ave (btw Buchanan St & Solano A...
# 3   [10140 San Pablo Ave, El Cerrito, CA 94530, Un...
# 4   [7525 Fairmount Ave, El Cerrito, CA 94530, Uni...
# 5   [3288 Pierce St (at Central Ave), Richmond, CA...
# 6   [1403 Solano Ave (at Carmel), Albany, CA 94706...
# 7   [809 San Pablo Ave, Albany, CA 94706, United S...
# 8   [854 San Pablo Ave (Solano Ave), Albany, CA 94...
# 9   [977 San Pablo Ave (Buchanan), Albany, CA 9470...
# 10  [3288 Pierce St Ste A107, Richmond, CA 94804, ...
# 11  [1105 Solano Ave, Albany, CA 94706, United Sta...
# 12  [10140 San Pablo Ave, El Cerrito, CA 94530, Un...
# 13  [938 San Pablo Ave, Albany, CA 94706, United S...
# 14  [10086 San Pablo Ave (at Central Ave.), El Cer...
# 15  [1335 Solano Ave (at Ramona Ave), Albany, CA 9...
# 16  [1410 Solano Ave, Albany, CA 94706, United Sta...
# 17  [3288 Pierce St Ste A116, Richmond, CA 94804, ...
# 18  [3150 Pierce St (Central Ave), Richmond, CA 94...
# 19  [1133 Solano Ave, Albany, CA 94706, United Sta...
# 20  [1369 Solano Ave, Albany, CA 94706, United Sta...
#
#                           id
# 0   4b37dad4f964a520834725e3
# 1   4e0a32ad22714194998c521c
# 2   4ae38d8df964a5208f9621e3
# 3   4b9d4208f964a520b59d36e3
# 4   4a63dc5cf964a520efc51fe3
# 5   4a76272ff964a52068e21fe3
# 6   52239a12498e5bad72298d8d
# 7   4f329c5819836c91c7e8994b
# 8   4a45b266f964a52075a81fe3
# 9   501994e7e4b00b6bfd7760a9
# 10  4bf19fcb78cec92891a0ba86
# 11  4a9df122f964a520dd3920e3
# 12  4f32b05519836c91c7f0120f
# 13  4bc1339fabf495217cc7c093
# 14  4cbfa7d19ca85481a714b816
# 15  51d35be7498ed50ed1db6cd3
# 16  4b9c49b7f964a520315c36e3
# 17  4acba3a9f964a520bcc420e3
# 18  4c5e06927f661b8d6f364d1c
# 19  578008a7498efd93529024bf
# 20  4c6ccdd065eda0938d0d4dd0

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around Albany Bowl

# add a red circle marker to represent the Albany Bowl
folium.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Albany Bowl',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Italian restaurants as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
Albany_grouped = dataframe_filtered.groupby('categories').mean().reset_index()
Albany_grouped
# Out:
#                    categories        lat         lng  distance
# 0              Breakfast Spot  37.904134 -122.291667    1210.0
# 1                        Café  37.890967 -122.290534    1093.0
# 2          Chinese Restaurant  37.895013 -122.301895     856.0
# 3          Dim Sum Restaurant  37.900902 -122.305511     714.5
# 4                        Food  37.903130 -122.303386     798.0
# 5         Japanese Restaurant  37.889625 -122.298675     760.5
# 6    Mediterranean Restaurant  37.890500 -122.297764     697.0
# 7            Ramen Restaurant  37.899048 -122.307392     639.0
# 8                  Restaurant  37.890647 -122.289153    1215.0
# 9   South American Restaurant  37.890919 -122.289919    1142.0
# 10            Thai Restaurant  37.890006 -122.298742     718.0
# 11      Vietnamese Restaurant  37.900609 -122.305114     652.0

# %% [markdown]
# ## Foursquare Expore

# %%
radiusEX = 500
LIMITEX = 500

# %%
# create URL Expore Query

url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    latitude, 
    longitude, 
    radiusEX, 
    LIMITEX)
url
# Out:
# 'https://api.foursquare.com/v2/venues/explore?&client_id=PQ05J4YNJMO22NWSMAYDERTCAU3FPRQO5VDVIDIGOBOBLCKZ&client_secret=ZDKTYSQ3AXJCTCYFLBCQA2QXRT4FPZWUUW4RAA4O2QDRCVFA&v=20200603&ll=37.8961913,-122.3010785&radius=500&limit=500'

# %%
resultsEX = requests.get(url).json()
resultsEX
# Out:
# {'meta': {'code': 200, 'requestId': '5ed93d9b69babe001bf2a88f'},
#  'response': {'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': '$-$$$$', 'key': 'price'},
#     {'name': 'Open now', 'key': 'openNow'}]},
#   'headerLocation': 'Albany',
#   'headerFullLocation': 'Albany',
#   'headerLocationGranularity': 'city',
#   'totalResults': 43,
#   'suggestedBounds': {'ne': {'lat': 37.9006913045, 'lng': -122.29538662235403},
#    'sw': {'lat': 37.891691295499996, 'lng': -122.30677037764598}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ae28a6cf964a520eb8e21e3',
#        'name': 'El Autlense Taco Truck',
#        'location': {'lat': 37.89477547928308,
#         'lng': -122.30010207390578,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.89477547928308,
#           'lng': -122.30010207390578}],
#         'distance': 179,
#         'cc': 'US',
#         'city': 'Albany',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['Albany, CA', 'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1cb941735',
#          'name': 'Food Truck',
#          'pluralName': 'Food Trucks',
#          'shortName': 'Food Truck',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ae28a6cf964a520eb8e21e3-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ad7d3bdf964a520230f21e3',
#        'name': "Al's Big Burger",
#        'location': {'address': '437 San Pablo Ave',
#         'crossStreet': 'at Brighton Ave.',
#         'lat': 37.89688128577032,
#         'lng': -122.3008513116458,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.89688128577032,
#           'lng': -122.3008513116458},
#          {'label': 'entrance', 'lat': 37.896893, 'lng': -122.300892}],
#         'distance': 79,
#         'postalCode': '94706',
#         'cc': 'US',
#         'city': 'Albany',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['437 San Pablo Ave (at Brighton Ave.)',
#          'Albany, CA 94706',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16c941735',
#          'name': 'Burger Joint',
#          'pluralName': 'Burger Joints',
#          'shortName': 'Burgers',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burger_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1876577',
#         'url': 'https://www.grubhub.com/restaurant/als-big-burger-437-san-pablo-avenue-albany/1876577?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1876577',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ad7d3bdf964a520230f21e3-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ca353875e3076b07e19f40c',
#        'name': 'Suhaila Salimpour School of Belly Dance',
#        'location': {'address': '425 San Pablo Ave',
#         'lat': 37.897517,
#         'lng': -122.30093400000001,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.897517,
#           'lng': -122.30093400000001},
#          {'label': 'entrance', 'lat': 37.897426, 'lng': -122.301045}],
#         'distance': 148,
#         'postalCode': '94706',
#         'cc': 'US',
#         'city': 'Albany',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['425 San Pablo Ave',
#          'Albany, CA 94706',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d134941735',
#          'name': 'Dance Studio',
#          'pluralName': 'Dance Studios',
#          'shortName': 'Dance Studio',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/performingarts_dancestudio_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ca353875e3076b07e19f40c-2'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '463cf4b0f964a52038461fe3',
#        'name': "Trader Joe's",
#        'location': {'address': '225 El Cerrito Plaza',
#         'crossStreet': 'at Carlson Blvd.',
#         'lat': 37.89878047652955,
#         'lng': -122.29963052790721,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.89878047652955,
#           'lng': -122.29963052790721}],
#         'distance': 315,
#         'postalCode': '94530',
#         'cc': 'US',
#         'city': 'El Cerrito',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['225 El Cerrito Plaza (at Carlson Blvd.)',
#          'El Cerrito, CA 94530',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d118951735',
#          'name': 'Grocery Store',
#          'pluralName': 'Grocery Stores',
#          'shortName': 'Grocery Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-463cf4b0f964a52038461fe3-3'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4a8a406ef964a520160a20e3',
#        'name': 'Hotsy Totsy Club',
#        'location': {'address': '601 San Pablo Ave',
#         'crossStreet': 'at Garfield Ave.',
#         'lat': 37.89499951041763,
#         'lng': -122.3002838958273,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.89499951041763,
#           'lng': -122.3002838958273},
#          {'label': 'entrance', 'lat': 37.89501, 'lng': -122.300285}],
#         'distance': 149,
#         'postalCode': '94706',
#         'cc': 'US',
#         'city': 'Albany',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['601 San Pablo Ave (at Garfield Ave.)',
#          'Albany, CA 94706',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d116941735',
#          'name': 'Bar',
#          'pluralName': 'Bars',
#          'shortName': 'Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4a8a406ef964a520160a20e3-4'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4a983740f964a520092b20e3',
#        'name': 'The Junket',
#        'location': {'address': '235 El Cerrito Plz',
#         'lat': 37.89892225830175,
#         'lng': -122.29906564448517,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.89892225830175,
#           'lng': -122.29906564448517},
#          {'label': 'entrance', 'lat': 37.899908, 'lng': -122.297674}],
#         'distance': 351,
#         'postalCode': '94530',
#         'cc': 'US',
#         'city': 'El Cerrito',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['235 El Cerrito Plz',
#          'El Cerrito, CA 94530',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d10d941735',
#          'name': 'German Restaurant',
#          'pluralName': 'German Restaurants',
#          'shortName': 'German',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/german_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1874899',
#         'url': 'https://www.grubhub.com/restaurant/junket-235-el-cerrito-plaza-el-cerrito/1874899?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1874899',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4a983740f964a520092b20e3-5'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5a487d8f0c9f311aea8e0850',
#        'name': 'Ocean View Brew Works',
#        'location': {'address': '627 San Pablo Ave',
#         'crossStreet': 'Castro St',
#         'lat': 37.89415480505313,
#         'lng': -122.30003816409457,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.89415480505313,
#           'lng': -122.30003816409457},
#          {'label': 'entrance', 'lat': 37.894175, 'lng': -122.299967}],
#         'distance': 244,
#         'postalCode': '94706',
#         'cc': 'US',
#         'city': 'Albany',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['627 San Pablo Ave (Castro St)',
#          'Albany, CA 94706',
#          'United States']},
#        'categories': [{'id': '50327c8591d4c4b30a586d5d',
#          'name': 'Brewery',
#          'pluralName': 'Breweries',
#          'shortName': 'Brewery',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5a487d8f0c9f311aea8e0850-6'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '462b9228f964a520df451fe3',
#        'name': 'Albany Bowl',
#        'location': {'address': '540 San Pablo Ave',
#         'crossStreet': 'at Clay St.',
#         'lat': 37.89624868070344,
#         'lng': -122.3010901182736,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.89624868070344,
#           'lng': -122.3010901182736}],
#         'distance': 6,
#         'postalCode': '94706',
#         'cc': 'US',
#         'city': 'Albany',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['540 San Pablo Ave (at Clay St.)',
#          'Albany, CA 94706',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e4931735',
#          'name': 'Bowling Alley',
#          'pluralName': 'Bowling Alleys',
#          'shortName': 'Bowling Alley',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/bowling_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-462b9228f964a520df451fe3-7'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '562bfabd498e6542c6313acd',
#        'name': 'Pho Ao Sen',
#        'location': {'address': '665 San Pablo Ave',
#         'crossStreet': 'Portland',
#         'lat': 37.89372134226513,
#         'lng': -122.29993570000028,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.89372134226513,
#           'lng': -122.29993570000028}],
#         'distance': 292,
#         'postalCode': '94706',
#         'cc': 'US',
#         'city': 'Albany',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['665 San Pablo Ave (Portland)',
#          'Albany, CA 94706',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d14a941735',
#          'name': 'Vietnamese Restaurant',
#          'pluralName': 'Vietnamese Restaurants',
#          'shortName': 'Vietnamese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vietnamese_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-562bfabd498e6542c6313acd-8'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4a903f01f964a520c51620e3',
#        'name': "Chef's Chinese Food",
#        'location': {'address': '233 El Cerrito Plz',
#         'lat': 37.898936486410385,
#         'lng': -122.29917415619533,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.898936486410385,
#           'lng': -122.29917415619533},
#          {'label': 'entrance', 'lat': 37.899858, 'lng': -122.297648}],
#         'distance': 348,
#         'postalCode': '94530',
#         'cc': 'US',
#         'city': 'El Cerrito',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['233 El Cerrito Plz',
#          'El Cerrito, CA 94530',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d145941735',
#          'name': 'Chinese Restaurant',
#          'pluralName': 'Chinese Restaurants',
#          'shortName': 'Chinese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4a903f01f964a520c51620e3-9'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d71bdde27ddb60c9a61c31b',
#        'name': 'Nails by Vivian',
#        'location': {'address': '9925 San Pablo Ave',
#         'crossStreet': 'Carlson',
#         'lat': 37.89933215671344,
#         'lng': -122.30220069069257,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.89933215671344,
#           'lng': -122.30220069069257},
#          {'label': 'entrance', 'lat': 37.899399, 'lng': -122.30223}],
#         'distance': 363,
#         'postalCode': '94530',
#         'cc': 'US',
#         'city': 'El Cerrito',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['9925 San Pablo Ave (Carlson)',
#          'El Cerrito, CA 94530',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d10c951735',
#          'name': 'Cosmetics Shop',
#          'pluralName': 'Cosmetics Shops',
#          'shortName': 'Cosmetics',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/beauty_cosmetic_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d71bdde27ddb60c9a61c31b-10'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b6dc42df964a520e38d2ce3',
#        'name': 'El Cerrito Farmers Market',
#        'location': {'address': 'El Cerrito Plaza',
#         'lat': 37.8985636500789,
#         'lng': -122.30013529493765,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.8985636500789,
#           'lng': -122.30013529493765}],
#         'distance': 276,
#         'postalCode': '94530',
#         'cc': 'US',
#         'city': 'El Cerrito',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['El Cerrito Plaza',
#          'El Cerrito, CA 94530',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1fa941735',
#          'name': 'Farmers Market',
#          'pluralName': 'Farmers Markets',
#          'shortName': "Farmer's Market",
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_farmersmarket_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b6dc42df964a520e38d2ce3-11'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b046fa7f964a520255422e3',
#        'name': 'Albany Hill Park',
#        'location': {'address': 'Albany Hill Park',
#         'lat': 37.89452876780731,
#         'lng': -122.30429891531625,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.89452876780731,
#           'lng': -122.30429891531625}],
#         'distance': 338,
#         'postalCode': '94706',
#         'cc': 'US',
#         'city': 'Albany',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['Albany Hill Park',
#          'Albany, CA 94706',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d159941735',
#          'name': 'Trail',
#          'pluralName': 'Trails',
#          'shortName': 'Trail',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/hikingtrail_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b046fa7f964a520255422e3-12'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cd490f0886cb60cfee17e89',
#        'name': 'El Cerrito Plaza',
#        'location': {'address': '2000-8000 El Cerrito Plz',
#         'lat': 37.8997778,
#         'lng': -122.2993757,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.8997778,
#           'lng': -122.2993757}],
#         'distance': 426,
#         'postalCode': '94530',
#         'cc': 'US',
#         'city': 'El Cerrito',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['2000-8000 El Cerrito Plz',
#          'El Cerrito, CA 94530',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d164941735',
#          'name': 'Plaza',
#          'pluralName': 'Plazas',
#          'shortName': 'Plaza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/plaza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4cd490f0886cb60cfee17e89-13'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d8767c0651041bdff0a9b30',
#        'name': "See's Candies",
#        'location': {'address': '160 El Cerrito Plz',
#         'lat': 37.89902245020435,
#         'lng': -122.30008477125934,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.89902245020435,
#           'lng': -122.30008477125934}],
#         'distance': 327,
#         'postalCode': '94530',
#         'cc': 'US',
#         'city': 'El Cerrito',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['160 El Cerrito Plz',
#          'El Cerrito, CA 94530',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d117951735',
#          'name': 'Candy Store',
#          'pluralName': 'Candy Stores',
#          'shortName': 'Candy Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/candystore_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d8767c0651041bdff0a9b30-14'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5725485c498e0bb2afc24b9a',
#        'name': 'Daiso Japan',
#        'location': {'address': '7000 El Cerrito Plz',
#         'lat': 37.89941981600992,
#         'lng': -122.30170533832056,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.89941981600992,
#           'lng': -122.30170533832056},
#          {'label': 'entrance', 'lat': 37.899387, 'lng': -122.301632}],
#         'distance': 363,
#         'postalCode': '94530',
#         'cc': 'US',
#         'city': 'El Cerrito',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['7000 El Cerrito Plz',
#          'El Cerrito, CA 94530',
#          'United States']},
#        'categories': [{'id': '52dea92d3cf9994f4e043dbb',
#          'name': 'Discount Store',
#          'pluralName': 'Discount Stores',
#          'shortName': 'Discount Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/discountstore_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5725485c498e0bb2afc24b9a-15'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '51322c14fe7021753815e56f',
#        'name': 'Albany Taproom',
#        'location': {'address': '745 San Pablo Ave',
#         'crossStreet': 'at Washington Ave',
#         'lat': 37.89242990660721,
#         'lng': -122.29939054204354,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.89242990660721,
#           'lng': -122.29939054204354}],
#         'distance': 444,
#         'postalCode': '94706',
#         'cc': 'US',
#         'city': 'Albany',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['745 San Pablo Ave (at Washington Ave)',
#          'Albany, CA 94706',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d116941735',
#          'name': 'Bar',
#          'pluralName': 'Bars',
#          'shortName': 'Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-51322c14fe7021753815e56f-16'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '517ac959e4b07e37ff7f1bd8',
#        'name': 'Chipotle Mexican Grill',
#        'location': {'address': '9901 San Pablo Ave',
#         'crossStreet': 'San Pablo Ave',
#         'lat': 37.89920809436757,
#         'lng': -122.30230887177561,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.89920809436757,
#           'lng': -122.30230887177561}],
#         'distance': 352,
#         'postalCode': '94530',
#         'cc': 'US',
#         'city': 'El Cerrito',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['9901 San Pablo Ave (San Pablo Ave)',
#          'El Cerrito, CA 94530',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1c1941735',
#          'name': 'Mexican Restaurant',
#          'pluralName': 'Mexican Restaurants',
#          'shortName': 'Mexican',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mexican_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-517ac959e4b07e37ff7f1bd8-17'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4a8c8890f964a520640e20e3',
#        'name': 'Club Mallard',
#        'location': {'address': '752 San Pablo Ave',
#         'crossStreet': 'at Washington Ave.',
#         'lat': 37.89236521172983,
#         'lng': -122.2998375643168,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.89236521172983,
#           'lng': -122.2998375643168},
#          {'label': 'entrance', 'lat': 37.892411, 'lng': -122.299818}],
#         'distance': 439,
#         'postalCode': '94706',
#         'cc': 'US',
#         'city': 'Albany',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['752 San Pablo Ave (at Washington Ave.)',
#          'Albany, CA 94706',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d116941735',
#          'name': 'Bar',
#          'pluralName': 'Bars',
#          'shortName': 'Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4a8c8890f964a520640e20e3-18'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4fdbaf81e4b015c11dfe4c66',
#        'name': 'Goodwill',
#        'location': {'address': '505 San Pablo Ave',
#         'crossStreet': 'Brighton Ave.',
#         'lat': 37.89651828944192,
#         'lng': -122.30068908491212,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.89651828944192,
#           'lng': -122.30068908491212},
#          {'label': 'entrance', 'lat': 37.896493, 'lng': -122.300779}],
#         'distance': 49,
#         'postalCode': '94706',
#         'cc': 'US',
#         'city': 'Albany',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['505 San Pablo Ave (Brighton Ave.)',
#          'Albany, CA 94706',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d101951735',
#          'name': 'Thrift / Vintage Store',
#          'pluralName': 'Thrift / Vintage Stores',
#          'shortName': 'Thrift / Vintage',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4fdbaf81e4b015c11dfe4c66-19'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '59f3a60048b04e778801e229',
#        'name': 'MOD Pizza',
#        'location': {'address': '5040 El Cerrito Plaza',
#         'lat': 37.9004097783646,
#         'lng': -122.29989986784659,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.9004097783646,
#           'lng': -122.29989986784659}],
#         'distance': 480,
#         'postalCode': '94530',
#         'cc': 'US',
#         'city': 'El Cerrito',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['5040 El Cerrito Plaza',
#          'El Cerrito, CA 94530',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1ca941735',
#          'name': 'Pizza Place',
#          'pluralName': 'Pizza Places',
#          'shortName': 'Pizza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '572014962'}},
#       'referralId': 'e-0-59f3a60048b04e778801e229-20'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b68a1c0f964a520f0832be3',
#        'name': 'Waikiki Hawaiian BBQ',
#        'location': {'address': '9935 San Pablo Ave',
#         'lat': 37.89937512467337,
#         'lng': -122.30225201319212,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.89937512467337,
#           'lng': -122.30225201319212}],
#         'distance': 369,
#         'postalCode': '94530',
#         'cc': 'US',
#         'city': 'El Cerrito',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['9935 San Pablo Ave',
#          'El Cerrito, CA 94530',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d142941735',
#          'name': 'Asian Restaurant',
#          'pluralName': 'Asian Restaurants',
#          'shortName': 'Asian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b68a1c0f964a520f0832be3-21'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '468aa0d2f964a5205f481fe3',
#        'name': "Peet's Coffee & Tea",
#        'location': {'address': '9895 San Pablo Ave,',
#         'lat': 37.898813,
#         'lng': -122.301995,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.898813,
#           'lng': -122.301995},
#          {'label': 'entrance', 'lat': 37.898731, 'lng': -122.301906}],
#         'distance': 302,
#         'postalCode': '94530',
#         'cc': 'US',
#         'city': 'El Cerrito',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['9895 San Pablo Ave,',
#          'El Cerrito, CA 94530',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1832968',
#         'url': 'https://www.grubhub.com/restaurant/peets-coffee--tea-9895-san-pablo-avenue-el-cerrito/1832968?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1832968',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-468aa0d2f964a5205f481fe3-22'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4af27180f964a520b8e721e3',
#        'name': 'Yammy Sushi',
#        'location': {'address': '195 El Cerrito Plz',
#         'lat': 37.89868604146332,
#         'lng': -122.30001968127306,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.89868604146332,
#           'lng': -122.30001968127306}],
#         'distance': 292,
#         'postalCode': '94530',
#         'cc': 'US',
#         'city': 'El Cerrito',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['195 El Cerrito Plz',
#          'El Cerrito, CA 94530',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1d2941735',
#          'name': 'Sushi Restaurant',
#          'pluralName': 'Sushi Restaurants',
#          'shortName': 'Sushi',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1711348',
#         'url': 'https://www.grubhub.com/restaurant/yammy-sushi-195-el-cerrito-plaza-el-cerrito/1711348?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1711348',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '96656577'}},
#       'referralId': 'e-0-4af27180f964a520b8e721e3-23'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4a9b33e1f964a520bd3420e3',
#        'name': 'Mel-O-Dee',
#        'location': {'address': '240 El Cerrito Plz',
#         'lat': 37.89916239647125,
#         'lng': -122.29900230762306,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.89916239647125,
#           'lng': -122.29900230762306},
#          {'label': 'entrance', 'lat': 37.899934, 'lng': -122.297774}],
#         'distance': 377,
#         'postalCode': '94530',
#         'cc': 'US',
#         'city': 'El Cerrito',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['240 El Cerrito Plz',
#          'El Cerrito, CA 94530',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d116941735',
#          'name': 'Bar',
#          'pluralName': 'Bars',
#          'shortName': 'Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4a9b33e1f964a520bd3420e3-24'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b0c4f2ef964a520ee3a23e3',
#        'name': 'Jamba Juice',
#        'location': {'address': '5030 El Cerrito Plaza,',
#         'crossStreet': 'at Fairmount',
#         'lat': 37.900524,
#         'lng': -122.299952,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.900524,
#           'lng': -122.299952},
#          {'label': 'entrance', 'lat': 37.90055, 'lng': -122.299909}],
#         'distance': 492,
#         'postalCode': '94530',
#         'cc': 'US',
#         'city': 'El Cerrito',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['5030 El Cerrito Plaza, (at Fairmount)',
#          'El Cerrito, CA 94530',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d112941735',
#          'name': 'Juice Bar',
#          'pluralName': 'Juice Bars',
#          'shortName': 'Juice Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/juicebar_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1198507',
#         'url': 'https://www.grubhub.com/restaurant/jamba-5030-el-cerrito-plz-ste-e-1-el-cerrito/1198507?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1198507',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b0c4f2ef964a520ee3a23e3-25'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4be5c50ccf200f4776b3133c',
#        'name': 'GNC',
#        'location': {'address': '230 El Cerrito Plz',
#         'lat': 37.89928,
#         'lng': -122.29896000000001,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.89928,
#           'lng': -122.29896000000001},
#          {'label': 'entrance', 'lat': 37.899807, 'lng': -122.297623}],
#         'distance': 390,
#         'postalCode': '94530',
#         'cc': 'US',
#         'city': 'El Cerrito',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['230 El Cerrito Plz',
#          'El Cerrito, CA 94530',
#          'United States']},
#        'categories': [{'id': '5744ccdfe4b0c0459246b4cd',
#          'name': 'Supplement Shop',
#          'pluralName': 'Supplement Shops',
#          'shortName': 'Supplement Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/lab_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4be5c50ccf200f4776b3133c-26'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ada7e8df964a5200b2321e3',
#        'name': 'Mangia Mangia',
#        'location': {'address': '755 San Pablo Ave',
#         'lat': 37.892148999999996,
#         'lng': -122.299123,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.892148999999996,
#           'lng': -122.299123},
#          {'label': 'entrance', 'lat': 37.892065, 'lng': -122.299338}],
#         'distance': 481,
#         'postalCode': '94706',
#         'cc': 'US',
#         'city': 'Albany',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['755 San Pablo Ave',
#          'Albany, CA 94706',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ada7e8df964a5200b2321e3-27'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c82d8472f1c236a02df3d43',
#        'name': 'Supercuts',
#        'location': {'address': '350 El Cerrito Plz',
#         'lat': 37.899715964469976,
#         'lng': -122.29855958020772,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.899715964469976,
#           'lng': -122.29855958020772}],
#         'distance': 450,
#         'postalCode': '94530',
#         'cc': 'US',
#         'city': 'El Cerrito',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['350 El Cerrito Plz',
#          'El Cerrito, CA 94530',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d110951735',
#          'name': 'Salon / Barbershop',
#          'pluralName': 'Salons / Barbershops',
#          'shortName': 'Salon / Barbershop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/salon_barber_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c82d8472f1c236a02df3d43-28'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4a7b5d67f964a520cdea1fe3',
#        'name': 'Bed Bath & Beyond',
#        'location': {'address': '6000 El Cerrito Plz',
#         'lat': 37.9002545,
#         'lng': -122.300507,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.9002545,
#           'lng': -122.300507},
#          {'label': 'entrance', 'lat': 37.900082, 'lng': -122.300668}],
#         'distance': 455,
#         'postalCode': '94530',
#         'cc': 'US',
#         'city': 'El Cerrito',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['6000 El Cerrito Plz',
#          'El Cerrito, CA 94530',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1f8941735',
#          'name': 'Furniture / Home Store',
#          'pluralName': 'Furniture / Home Stores',
#          'shortName': 'Furniture / Home',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/furniture_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4a7b5d67f964a520cdea1fe3-29'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bdf2f726198c9b67c4016ff',
#        'name': 'Verizon',
#        'location': {'address': '410 El Cerrito Plz',
#         'lat': 37.8993604,
#         'lng': -122.2986482,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.8993604,
#           'lng': -122.2986482}],
#         'distance': 412,
#         'postalCode': '94530',
#         'cc': 'US',
#         'city': 'El Cerrito',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['410 El Cerrito Plz',
#          'El Cerrito, CA 94530',
#          'United States']},
#        'categories': [{'id': '4f04afc02fb6e1c99f3db0bc',
#          'name': 'Mobile Phone Shop',
#          'pluralName': 'Mobile Phone Shops',
#          'shortName': 'Mobile Phones',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/mobilephoneshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bdf2f726198c9b67c4016ff-30'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ae209e8f964a5200c8a21e3',
#        'name': 'Petco',
#        'location': {'address': '420 El Cerrito Plaza',
#         'lat': 37.899430966236075,
#         'lng': -122.2987225716093,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.899430966236075,
#           'lng': -122.2987225716093}],
#         'distance': 415,
#         'postalCode': '94530',
#         'cc': 'US',
#         'city': 'El Cerrito',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['420 El Cerrito Plaza',
#          'El Cerrito, CA 94530',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d100951735',
#          'name': 'Pet Store',
#          'pluralName': 'Pet Stores',
#          'shortName': 'Pet Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pet_store_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ae209e8f964a5200c8a21e3-31'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4baee247f964a52081df3be3',
#        'name': 'Taco Bell',
#        'location': {'address': '635 San Pablo Ave',
#         'lat': 37.89407253312914,
#         'lng': -122.29989167375713,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.89407253312914,
#           'lng': -122.29989167375713},
#          {'label': 'entrance', 'lat': 37.894049, 'lng': -122.299964}],
#         'distance': 257,
#         'postalCode': '94706',
#         'cc': 'US',
#         'city': 'Albany',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['635 San Pablo Ave',
#          'Albany, CA 94706',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16e941735',
#          'name': 'Fast Food Restaurant',
#          'pluralName': 'Fast Food Restaurants',
#          'shortName': 'Fast Food',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '918010',
#         'url': 'https://www.grubhub.com/restaurant/taco-bell-635-san-pablo-ave-albany/918010?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=918010',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4baee247f964a52081df3be3-32'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4aebb069f964a5206ac421e3',
#        'name': 'JOANN Fabrics and Crafts',
#        'location': {'address': '300 El Cerrito Plz',
#         'lat': 37.89972015916064,
#         'lng': -122.2986452023743,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.89972015916064,
#           'lng': -122.2986452023743},
#          {'label': 'entrance', 'lat': 37.899887, 'lng': -122.297924}],
#         'distance': 447,
#         'postalCode': '94530',
#         'cc': 'US',
#         'city': 'El Cerrito',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['300 El Cerrito Plz',
#          'El Cerrito, CA 94530',
#          'United States']},
#        'categories': [{'id': '52f2ab2ebcbc57f1066b8b26',
#          'name': 'Fabric Shop',
#          'pluralName': 'Fabric Shops',
#          'shortName': 'Fabric Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4aebb069f964a5206ac421e3-33'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c5069eddcb5d13aeedbff08',
#        'name': 'Galvin Appliance',
#        'location': {'address': '619 San Pablo Ave',
#         'lat': 37.894513,
#         'lng': -122.299904,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.894513,
#           'lng': -122.299904},
#          {'label': 'entrance', 'lat': 37.894359, 'lng': -122.299829}],
#         'distance': 213,
#         'postalCode': '94706',
#         'cc': 'US',
#         'city': 'Albany',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['619 San Pablo Ave',
#          'Albany, CA 94706',
#          'United States']},
#        'categories': [{'id': '5454144b498ec1f095bff2f2',
#          'name': 'Construction & Landscaping',
#          'pluralName': 'Construction & Landscaping',
#          'shortName': 'Construction',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/realestate_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c5069eddcb5d13aeedbff08-34'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4aceaeeff964a520afd120e3',
#        'name': 'Wingstop',
#        'location': {'address': '340 El Cerrito Plz',
#         'lat': 37.89969975425102,
#         'lng': -122.29839059992024,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.89969975425102,
#           'lng': -122.29839059992024}],
#         'distance': 456,
#         'postalCode': '94530',
#         'cc': 'US',
#         'city': 'El Cerrito',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['340 El Cerrito Plz',
#          'El Cerrito, CA 94530',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d14c941735',
#          'name': 'Wings Joint',
#          'pluralName': 'Wings Joints',
#          'shortName': 'Wings',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/wings_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4aceaeeff964a520afd120e3-35'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4a870fb5f964a520640220e3',
#        'name': 'Gymboree Play & Learn',
#        'location': {'address': '704 El Cerrito Plz',
#         'lat': 37.89899171066985,
#         'lng': -122.29929922914151,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.89899171066985,
#           'lng': -122.29929922914151}],
#         'distance': 348,
#         'postalCode': '94530',
#         'cc': 'US',
#         'city': 'El Cerrito',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['704 El Cerrito Plz',
#          'El Cerrito, CA 94530',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d175941735',
#          'name': 'Gym / Fitness Center',
#          'pluralName': 'Gyms or Fitness Centers',
#          'shortName': 'Gym / Fitness',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4a870fb5f964a520640220e3-36'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cdb6e51adcc2c0fb56aae79',
#        'name': 'Ojas Yoga Center',
#        'location': {'address': '707 El Cerrito Plz',
#         'crossStreet': 'San Pablo',
#         'lat': 37.89908444901075,
#         'lng': -122.29919402834334,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.89908444901075,
#           'lng': -122.29919402834334}],
#         'distance': 362,
#         'postalCode': '94530',
#         'cc': 'US',
#         'city': 'El Cerrito',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['707 El Cerrito Plz (San Pablo)',
#          'El Cerrito, CA 94530',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d102941735',
#          'name': 'Yoga Studio',
#          'pluralName': 'Yoga Studios',
#          'shortName': 'Yoga Studio',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4cdb6e51adcc2c0fb56aae79-37'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5ba68cf9dab4b1002cf2334b',
#        'name': 'Fuse Fitness',
#        'location': {'address': '727 San Pablo Ave',
#         'crossStreet': 'Portland Ave',
#         'lat': 37.89298269616236,
#         'lng': -122.29982838477491,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.89298269616236,
#           'lng': -122.29982838477491}],
#         'distance': 373,
#         'postalCode': '94706',
#         'cc': 'US',
#         'city': 'Albany',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['727 San Pablo Ave (Portland Ave)',
#          'Albany, CA 94706',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d176941735',
#          'name': 'Gym',
#          'pluralName': 'Gyms',
#          'shortName': 'Gym',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5ba68cf9dab4b1002cf2334b-38'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4eb432a461af0dda8fcedfbf',
#        'name': 'Metta Traditional Thai Massage',
#        'location': {'address': '727 San Pablo Ave, Albany, CA 94706',
#         'lat': 37.892905526121524,
#         'lng': -122.29981124864948,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.892905526121524,
#           'lng': -122.29981124864948}],
#         'distance': 382,
#         'postalCode': '94706',
#         'cc': 'US',
#         'city': 'Albany',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['727 San Pablo Ave, Albany, CA 94706',
#          'Albany, CA 94706',
#          'United States']},
#        'categories': [{'id': '52f2ab2ebcbc57f1066b8b3c',
#          'name': 'Massage Studio',
#          'pluralName': 'Massage Studios',
#          'shortName': 'Massage Studio',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/spa_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4eb432a461af0dda8fcedfbf-39'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5b7e731a61f070002c4b8556',
#        'name': 'Sola Salon Studios',
#        'location': {'address': 'El Cerrito Plaza',
#         'lat': 37.899223,
#         'lng': -122.298917,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.899223,
#           'lng': -122.298917}],
#         'distance': 387,
#         'postalCode': '94530',
#         'cc': 'US',
#         'city': 'El Cerrito',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['El Cerrito Plaza',
#          'El Cerrito, CA 94530',
#          'United States']},
#        'categories': [{'id': '54541900498ea6ccd0202697',
#          'name': 'Health & Beauty Service',
#          'pluralName': 'Health & Beauty Services',
#          'shortName': 'Health & Beauty',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/salon_barber_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '571675683'}},
#       'referralId': 'e-0-5b7e731a61f070002c4b8556-40'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4dacdf6bfa8ca548ba16d9c6',
#        'name': 'WW (Weight Watchers)',
#        'location': {'address': '270 El Cerrito Plz',
#         'lat': 37.899428498473824,
#         'lng': -122.29865277305493,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.899428498473824,
#           'lng': -122.29865277305493},
#          {'label': 'entrance', 'lat': 37.899911, 'lng': -122.297849}],
#         'distance': 418,
#         'postalCode': '94530',
#         'cc': 'US',
#         'city': 'El Cerrito',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['270 El Cerrito Plz',
#          'El Cerrito, CA 94530',
#          'United States']},
#        'categories': [{'id': '590a0744340a5803fd8508c3',
#          'name': 'Weight Loss Center',
#          'pluralName': 'Weight Loss Centers',
#          'shortName': 'Weight Loss Center',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4dacdf6bfa8ca548ba16d9c6-41'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5ae4fa874c954c002cf8d90e',
#        'name': '(310) Eatery',
#        'location': {'address': '747 San Pablo Ave',
#         'crossStreet': 'Washington Ave',
#         'lat': 37.892409,
#         'lng': -122.29926200000001,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.892409,
#           'lng': -122.29926200000001},
#          {'label': 'entrance', 'lat': 37.892374, 'lng': -122.299433}],
#         'distance': 450,
#         'postalCode': '94706',
#         'cc': 'US',
#         'city': 'Albany',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['747 San Pablo Ave (Washington Ave)',
#          'Albany, CA 94706',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16c941735',
#          'name': 'Burger Joint',
#          'pluralName': 'Burger Joints',
#          'shortName': 'Burgers',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burger_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1525204',
#         'url': 'https://www.grubhub.com/restaurant/310-eatery-747-san-pablo-avenue-albany/1525204?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1525204',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5ae4fa874c954c002cf8d90e-42'}]}]}}

# %%
# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
venues = resultsEX['response']['groups'][0]['items']
    
nearby_venues = json_normalize(venues) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
nearby_venues =nearby_venues.loc[:, filtered_columns]

# filter the category for each row
nearby_venues['venue.categories'] = nearby_venues.apply(get_category_type, axis=1)

# clean columns
nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]

nearby_venues.head(100)
# Out:
#                                        name                  categories  \
# 0                    El Autlense Taco Truck                  Food Truck
# 1                           Al's Big Burger                Burger Joint
# 2   Suhaila Salimpour School of Belly Dance                Dance Studio
# 3                              Trader Joe's               Grocery Store
# 4                          Hotsy Totsy Club                         Bar
# 5                                The Junket           German Restaurant
# 6                     Ocean View Brew Works                     Brewery
# 7                               Albany Bowl               Bowling Alley
# 8                                Pho Ao Sen       Vietnamese Restaurant
# 9                       Chef's Chinese Food          Chinese Restaurant
# 10                          Nails by Vivian              Cosmetics Shop
# 11                El Cerrito Farmers Market              Farmers Market
# 12                         Albany Hill Park                       Trail
# 13                         El Cerrito Plaza                       Plaza
# 14                            See's Candies                 Candy Store
# 15                              Daiso Japan              Discount Store
# 16                           Albany Taproom                         Bar
# 17                   Chipotle Mexican Grill          Mexican Restaurant
# 18                             Club Mallard                         Bar
# 19                                 Goodwill      Thrift / Vintage Store
# 20                                MOD Pizza                 Pizza Place
# 21                     Waikiki Hawaiian BBQ            Asian Restaurant
# 22                      Peet's Coffee & Tea                 Coffee Shop
# 23                              Yammy Sushi            Sushi Restaurant
# 24                                Mel-O-Dee                         Bar
# 25                              Jamba Juice                   Juice Bar
# 26                                      GNC             Supplement Shop
# 27                            Mangia Mangia          Italian Restaurant
# 28                                Supercuts          Salon / Barbershop
# 29                        Bed Bath & Beyond      Furniture / Home Store
# 30                                  Verizon           Mobile Phone Shop
# 31                                    Petco                   Pet Store
# 32                                Taco Bell        Fast Food Restaurant
# 33                 JOANN Fabrics and Crafts                 Fabric Shop
# 34                         Galvin Appliance  Construction & Landscaping
# 35                                 Wingstop                 Wings Joint
# 36                    Gymboree Play & Learn        Gym / Fitness Center
# 37                         Ojas Yoga Center                 Yoga Studio
# 38                             Fuse Fitness                         Gym
# 39           Metta Traditional Thai Massage              Massage Studio
# 40                       Sola Salon Studios     Health & Beauty Service
# 41                     WW (Weight Watchers)          Weight Loss Center
# 42                             (310) Eatery                Burger Joint
#
#           lat         lng
# 0   37.894775 -122.300102
# 1   37.896881 -122.300851
# 2   37.897517 -122.300934
# 3   37.898780 -122.299631
# 4   37.895000 -122.300284
# 5   37.898922 -122.299066
# 6   37.894155 -122.300038
# 7   37.896249 -122.301090
# 8   37.893721 -122.299936
# 9   37.898936 -122.299174
# 10  37.899332 -122.302201
# 11  37.898564 -122.300135
# 12  37.894529 -122.304299
# 13  37.899778 -122.299376
# 14  37.899022 -122.300085
# 15  37.899420 -122.301705
# 16  37.892430 -122.299391
# 17  37.899208 -122.302309
# 18  37.892365 -122.299838
# 19  37.896518 -122.300689
# 20  37.900410 -122.299900
# 21  37.899375 -122.302252
# 22  37.898813 -122.301995
# 23  37.898686 -122.300020
# 24  37.899162 -122.299002
# 25  37.900524 -122.299952
# 26  37.899280 -122.298960
# 27  37.892149 -122.299123
# 28  37.899716 -122.298560
# 29  37.900255 -122.300507
# 30  37.899360 -122.298648
# 31  37.899431 -122.298723
# 32  37.894073 -122.299892
# 33  37.899720 -122.298645
# 34  37.894513 -122.299904
# 35  37.899700 -122.298391
# 36  37.898992 -122.299299
# 37  37.899084 -122.299194
# 38  37.892983 -122.299828
# 39  37.892906 -122.299811
# 40  37.899223 -122.298917
# 41  37.899428 -122.298653
# 42  37.892409 -122.299262

# %%
nearby_venues.shape
# Out:
# (43, 4)

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around Albany Bowl

# add a red circle marker to represent the Albany Bowl
folium.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Albany Bowl',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Italian restaurants as blue circle markers
for lat, lng, label in zip(nearby_venues.lat, nearby_venues.lng, nearby_venues.categories):
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## More Exporation, Checking to see if anything is Trending

# %%
# define URL
url3 = 'https://api.foursquare.com/v2/venues/trending?client_id={}&client_secret={}&ll={},{}&v={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION)
url3
# send GET request and get trending venues
# Out:
# 'https://api.foursquare.com/v2/venues/trending?client_id=PQ05J4YNJMO22NWSMAYDERTCAU3FPRQO5VDVIDIGOBOBLCKZ&client_secret=ZDKTYSQ3AXJCTCYFLBCQA2QXRT4FPZWUUW4RAA4O2QDRCVFA&ll=37.8961913,-122.3010785&v=20200603'

# %%
results3 = requests.get(url3).json()
results3
# Out:
# {'meta': {'code': 200, 'requestId': '5ed93eb61a4b0a001ba1deb6'},
#  'response': {'venues': []}}

# %%
if len(results3['response']['venues']) == 0:
    trending_venues_df = 'No trending venues are available at the moment!'
    
else:
    trending_venues = results3['response']['venues']
    trending_venues_df = json_normalize(trending_venues)

    # filter columns
    columns_filtered = ['name', 'categories'] + ['location.distance', 'location.city', 'location.postalCode', 'location.state', 'location.country', 'location.lat', 'location.lng']
    trending_venues_df = trending_venues_df.loc[:, columns_filtered]

    # filter the category for each row
    trending_venues_df['categories'] = trending_venues_df.apply(get_category_type, axis=1)

# %%
trending_venues_df
#no tredning venues
# Out:
# 'No trending venues are available at the moment!'

# %%
if len(results3['response']['venues']) == 0:
    venues_map3 = 'Cannot generate visual as no trending venues are available at the moment!'

else:
    venues_map3 = folium.Map(location=[latitude, longitude], zoom_start=15) # generate map centred around Ecco


    # add Ecco as a red circle mark
    folium.features.CircleMarker(
        [latitude, longitude],
        radius=10,
        popup='Ecco',
        fill=True,
        color='red',
        fill_color='red',
        fill_opacity=0.6
    ).add_to(venues_map3)


    # add the trending venues as blue circle markers
    for lat, lng, label in zip(trending_venues_df['location.lat'], trending_venues_df['location.lng'], trending_venues_df['name']):
        folium.features.CircleMarker(
            [lat, lng],
            radius=5,
            poup=label,
            fill=True,
            color='blue',
            fill_color='blue',
            fill_opacity=0.6
        ).add_to(venues_map3)

# %%
# display map
venues_map3
# Out:
# 'Cannot generate visual as no trending venues are available at the moment!'

# %%
# one hot encoding
manhattan_onehot = pd.get_dummies(manhattan_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
#manhattan_onehot['Neighborhood'] = manhattan_venues['Neighborhood'] 

# move neighborhood column to the first column
fixed_columns = [manhattan_onehot.columns[-1]] + list(manhattan_onehot.columns[:-1])
manhattan_onehot = manhattan_onehot[fixed_columns]

manhattan_onehot.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-bdd04409851e> in <module>
#       1 # one hot encoding
# ----> 2 manhattan_onehot = pd.get_dummies(manhattan_venues[['Venue Category']], prefix="", prefix_sep="")
#       3
#       4 # add neighborhood column back to dataframe
#       5 #manhattan_onehot['Neighborhood'] = manhattan_venues['Neighborhood']
#
# NameError: name 'manhattan_venues' is not defined

# %%
# set number of clusters
kclusters = 5

Albany_grouped_clustering = Albany_grouped
#.drop('Neighborhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(Albany_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-669fa8791586> in <module>
#       6
#       7 # run k-means clustering
# ----> 8 kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(Albany_grouped_clustering)
#       9
#      10 # check cluster labels generated for each row in the dataframe
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/cluster/_kmeans.py in fit(self, X, y, sample_weight)
#     992                                 dtype=[np.float64, np.float32],
#     993                                 order='C', copy=self.copy_x,
# --> 994                                 accept_large_sparse=False)
#     995         # verify that the number of samples given is larger than k
#     996         if _num_samples(X) < self.n_clusters:
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     418                     f"requires y to be passed, but the target y is None."
#     419                 )
# --> 420             X = check_array(X, **check_params)
#     421             out = X
#     422         else:
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      71                           FutureWarning)
#      72         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 73         return f(**kwargs)
#      74     return inner_f
#      75
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     597                     array = array.astype(dtype, casting="unsafe", copy=False)
#     598                 else:
# --> 599                     array = np.asarray(array, order=order, dtype=dtype)
#     600             except ComplexWarning:
#     601                 raise ValueError("Complex data not supported\n"
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/numpy/core/_asarray.py in asarray(a, dtype, order)
#      83
#      84     """
# ---> 85     return array(a, dtype, copy=False, order=order)
#      86
#      87
#
# ValueError: could not convert string to float: 'Vietnamese Restaurant'
